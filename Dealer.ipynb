# %%
import racko_bot
game = racko_bot.game.Dealer(60, 2)

# %%
game.deal()
# Out:
# [[3, 1, 46, 20, 29, 53, 45, 9, 40, 10],
#  [58, 42, 47, 16, 57, 17, 55, 21, 59, 41]]

# %%
game.top_card()
# Out:
# 34
